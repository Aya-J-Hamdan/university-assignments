# %% [markdown]
# <a href="https://colab.research.google.com/github/Aya-J-Hamdan/university-assignments/blob/main/Copy_of_AI_using_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def create_list():
 random_list=[1,2,5,6,8]
 value=int(input("enter the value:"))
 if value in random_list:
   print("the value exists in the list")
 else:
   print("the value does not exist in the list")

def caesar_ciper(message,shift):
  message="hello,world!"
  encrypted_message=''.join([chr(((ord(char)-65+shift)%26)+65) if char.isupper() else chr(((ord(char)-97+shift)%26)+97) if char.isalpha() else char for char in message])
  return encrypted_message

  shift=3
  encrypted_message=caesar_ciper(message, shift)
  print("original message:", message)
  print("encrypted message:",encrypted_message)

def reversal():
  word=input("input a string:")
  reversed_string=word[::-1]
  print("reversed string:", reversed_string)

def concatinate():
  first_name=input("enter your first name:")
  last_name=input("enter your last name:")
  print("concatinate:", first_name+last_name)

def MyList():
  my_list=[4,2,8,5,9,11,15]
  total=sum(my_list)
  maximum_number=max(my_list)
  minimum_number=min(my_list)
  print("sum of all numbers=", total)
  print("the maximum number:", maximum_number)
  print("the minimum number:", minimum_number)

def slicing():
  original_list=[1,2,3,4,5,6,7]
  first_three=original_list[:3]
  every_other_element=original_list[3:]
  print("the first three:", first_three)
  print("every other:", every_other_element)

def check():
  number=int(input("enter the number:"))
  if (number%2==0):
    print("this number is even")
  else:
    print("this number is odd")

def palindrome():
  string=input("enter a string:")
  if (string==string[::-1]):
    print("this string is a palindrome")
  else:
    print("its not a palindrome")

def unit_convert():
  conversion_factor=1.60
  miles=float(input("input in miles:"))
  kilometers=miles*conversion_factor
  print(f"{miles} miles is equal to {kilometers} kilometers.")

def bmi_calculate(height,weight):
  height=float(input("enter your height in centimeters:"))
  weight=float(input("enter your weight in kilograms"))
  height_in_meters=height/100
  bmi=weight/(height_in_meters**2)
  return bmi

  bmi=bmi_calculate(height,weight)
  print(f"your bmi is: {bmi}")

def guess_number():
    import random
    secret_number=random.randint(1,100)
    print("guess the number between 1 and 100")

    guess=int(input("enter your guess:"))
    if guess==secret_number:
     print("you guessed correctly!")

    elif guess < secret_number:
        print("too low, try again!")
    else:
      print("too high, try again!")


def vowel_count(input_string):
  input_string=input("enter a string:2")
  input_string=input_string.lower()
  vowels=['a','e','i','o','u']
  num_vowels=sum(1 for char in input_string if char in vowels)
  return num_vowels

  num_vowels=vowel_count(input_string)
  print(f"the string contains {num_vowels} vowels.")


def avg_find(numbers):
  numbers=input("enter the numbers").split()
  total=sum(numbers)
  average=total/len(numbers)
  return average

  numbers=list(map(float,numbers))
  avg=avg_find(numbers)
  print(f"the average of the numbers is:{avg}")


def main():
 print("hello,this is a python code selector, please select a number from 1 to 13:")
 choice=int(input(">>"))
 if choice==1:
  create_list()

 elif choice==2:
   caesar_ciper(message, shift)

 elif choice==3:
     reversal()

 elif choice==4:
     concatinate()

 elif choice==5:
     MyList()

 elif choice==6:
    slicing()

 elif choice==7:
    check()

 elif choice==8:
    palindrome()

 elif choice ==9:
    unit_convert()

 elif choice==10:
    bmi_calculate(height, weight)

 elif choice==11:
     guess_number()

 elif choice==12:
     vowel_count(input_string)

 elif choice==13:
   avg_find(numbers)

 else:
   print("invalid choice,please enter a number from 1 to 13")

main()
# Out:
# hello,this is a python code selector, please select a number from 1 to 13:
# >>13
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-ea6b8a0c609c> in <cell line: 157>()
#     155    print("invalid choice,please enter a number from 1 to 13")
#     156
# --> 157 main()
#
# <ipython-input-69-ea6b8a0c609c> in main()
#     150
#     151  elif choice==13:
# --> 152    avg_find(numbers)
#     153
#     154  else:
#
# NameError: name 'numbers' is not defined
